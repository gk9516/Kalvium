# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape data and save as CSV
def scrape_and_save_as_csv(url, csv_filename):
    # Fetch the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extracting data and preparing for CSV
    data_to_save = []

    # Extracting data from each row
    for row in soup.find_all('tr'):
        data_row = []

        # Skip first and last rows (headers and state summary)
        if row.find('th'):  # Skip header row
            continue
        if 'State Total' in row.text.strip():  # Skip state total row
            continue

        # Extracting data from each cell
        for cell in row.find_all('td'):
            data_row.append(cell.text.strip())

        if len(data_row) == 0:
            continue  # Skip empty rows (if any)

        # Add state name as the first column for the first valid data row
        data_to_save.append([state] + data_row)  # Include state name in each row

    # Write to CSV
    with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write headers
        csv_writer.writerow(['State', 'Party Name', 'Won', 'Leading', 'Total'])
        # Write data
        csv_writer.writerows(data_to_save)

    return data_to_save  # Return the data to be saved

# List of URLs for all states
state_urls = {
    'Andaman and Nicobar': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U01.htm',
    'Andhra Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S01.htm',
    'Arunachal Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S02.htm',
    'Assam': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S03.htm',
    'Bihar': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S04.htm',
    'Chandigarh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U02.htm',
    'Chhattisgarh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S26.htm',
    'Dadra and Nagar Haveli and Daman and Diu': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U03.htm',
    'Goa': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S05.htm',
    'Gujarat': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S06.htm',
    'Haryana': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S07.htm',
    'Himachal Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S08.htm',
    'Jammu and Kashmir': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U08.htm',
    'Jharkhand': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S27.htm',
    'Karnataka': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S10.htm',
    'Kerala': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S11.htm',
    'Ladhakh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U09.htm',
    'Lakshadweep': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U06.htm',
    'Madhya Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S12.htm',
    'Maharashtra': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S13.htm',
    'Manipur': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S14.htm',
    'Meghalaya': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S15.htm',
    'Mizoram': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S16.htm',
    'Nagaland': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S17.htm',
    'NCT OF Delhi': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U05.htm',
    'Odisha': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S18.htm',
    'Puducherry': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U07.htm',
    'Punjab': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S19.htm',
    'Rajasthan': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S20.htm',
    'Sikkim': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S21.htm',
    'Tamil Nadu': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S22.htm',
    'Telangana': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S29.htm',
    'Tripura': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S23.htm',
    'Uttar Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S24.htm',
    'Uttarakhand': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S28.htm',
    'West Bengal': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S25.htm'
}

# Prepare data to save to CSV
all_data_to_save = []

# Scraping and saving data for each state
for state, url in state_urls.items():
    data_for_state = scrape_and_save_as_csv(url, f'{state}_election_results.csv')
    if data_for_state is not None:  # Check if data is not None before extending
        all_data_to_save.extend(data_for_state)

# Write all data to a single CSV file
csv_filename = 'all_states_election_results.csv'
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile, delimiter='\t')  # Using tab delimiter for better readability
    # Write headers
    csv_writer.writerow(['State', 'Party Name', 'Won', 'Leading', 'Total'])
    # Write data
    csv_writer.writerows(all_data_to_save)

print(f'Saved all states election results to {csv_filename}')
# Out:
# Saved all states election results to all_states_election_results.csv

# %%
import csv

input_file = '/content/all_states_election_results_final.csv'  # Replace with your CSV file name
output_file = 'all_states_election_results_finals.csv'  # Replace with desired output file name

with open(input_file, 'r', newline='') as infile, open(output_file, 'w', newline='') as outfile:
    reader = csv.reader(infile, delimiter='\t')  # Assuming tabs separate columns
    writer = csv.writer(outfile)

    for row in reader:
        writer.writerow(row)

print(f'Successfully separated columns and saved to {output_file}.')
# Out:
# Successfully separated columns and saved to all_states_election_results_finals.csv.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to scrape data and return as DataFrame
def scrape_and_return_df(url):
    # Fetch the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extracting data and preparing for DataFrame
    data_to_return = []

    # Extracting data from each row
    state_name = ''
    for row in soup.find_all('tr'):
        data_row = []

        # Skip first and last rows (headers and state summary)
        if row.find('th'):  # Skip header row
            continue
        if 'State Total' in row.text.strip():  # Skip state total row
            continue

        # Extracting data from each cell
        for cell in row.find_all('td'):
            data_row.append(cell.text.strip())

        if len(data_row) == 0:
            continue  # Skip empty rows (if any)

        # If state name is not set, set it
        if not state_name:
            state_name = data_row[0]  # Assuming the first cell contains the state name

        # Add state name as the first column for the first valid data row
        if data_row[0].startswith('Total'):
            data_to_return.append([state_name] + data_row)  # Include state name in each row
            state_name = ''  # Reset state_name for the next state
        else:
            data_to_return.append([''] + data_row)  # Empty column for subsequent rows

    # Convert to DataFrame
    df = pd.DataFrame(data_to_return, columns=['State', 'Party Name', 'Won', 'Leading', 'Total'])

    return df

# List of URLs for all states
state_urls = {
    'Andaman and Nicobar': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U01.htm',
    'Andhra Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S01.htm',
    'Arunachal Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S02.htm',
    'Assam': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S03.htm',
    'Bihar': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S04.htm',
    'Chandigarh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U02.htm',
    'Chhattisgarh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S26.htm',
    'Dadra and Nagar Haveli and Daman and Diu': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U03.htm',
    'Goa': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S05.htm',
    'Gujarat': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S06.htm',
    'Haryana': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S07.htm',
    'Himachal Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S08.htm',
    'Jammu and Kashmir': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U08.htm',
    'Jharkhand': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S27.htm',
    'Karnataka': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S10.htm',
    'Kerala': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S11.htm',
    'Ladhakh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U09.htm',
    'Lakshadweep': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U06.htm',
    'Madhya Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S12.htm',
    'Maharashtra': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S13.htm',
    'Manipur': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S14.htm',
    'Meghalaya': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S15.htm',
    'Mizoram': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S16.htm',
    'Nagaland': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S17.htm',
    'NCT OF Delhi': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U05.htm',
    'Odisha': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S18.htm',
    'Puducherry': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U07.htm',
    'Punjab': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S19.htm',
    'Rajasthan': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S20.htm',
    'Sikkim': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S21.htm',
    'Tamil Nadu': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S22.htm',
    'Telangana': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S29.htm',
    'Tripura': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S23.htm',
    'Uttar Pradesh': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S24.htm',
    'Uttarakhand': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S28.htm',
    'West Bengal': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S25.htm'
}

# Prepare data to save to CSV
all_data_dfs = []

# Scraping data for each state and storing in DataFrame list
for state, url in state_urls.items():
    df_state = scrape_and_return_df(url)
    if df_state is not None:  # Check if data is not None before appending
        df_state['State'] = state  # Adding state column to DataFrame
        all_data_dfs.append(df_state)

# Concatenate all DataFrames into a single DataFrame
all_data_combined = pd.concat(all_data_dfs, ignore_index=True)

# Convert 'Total' column to numeric (integer)
all_data_combined['Total'] = pd.to_numeric(all_data_combined['Total'], errors='coerce')

# Calculate total constituencies for each state
constituencies_count = all_data_combined.groupby('State')['Total'].sum().reset_index()

# Display or further process constituencies_count DataFrame
print(constituencies_count)

# Optionally, save constituencies_count to CSV
constituencies_count.to_csv('total_constituencies_per_state.csv', index=False)
# Out:
#                                        State  Total
# 0                        Andaman and Nicobar      1
# 1                             Andhra Pradesh     25
# 2                          Arunachal Pradesh      2
# 3                                      Assam     14
# 4                                      Bihar     40
# 5                                 Chandigarh      1
# 6                               Chhattisgarh     11
# 7   Dadra and Nagar Haveli and Daman and Diu      2
# 8                                        Goa      2
# 9                                    Gujarat     26
# 10                                   Haryana     10
# 11                          Himachal Pradesh      4
# 12                         Jammu and Kashmir      5
# 13                                 Jharkhand     14
# 14                                 Karnataka     28
# 15                                    Kerala     20
# 16                                   Ladhakh      1
# 17                               Lakshadweep      1
# 18                            Madhya Pradesh     29
# 19                               Maharashtra     48
# 20                                   Manipur      2
# 21                                 Meghalaya      2
# 22                                   Mizoram      1
# 23                              NCT OF Delhi      7
# 24                                  Nagaland      1
# 25                                    Odisha     21
# 26                                Puducherry      1
# 27                                    Punjab     13
# 28                                 Rajasthan     25
# 29                                    Sikkim      1
# 30                                Tamil Nadu     39
# 31                                 Telangana     17
# 32                                   Tripura      2
# 33                             Uttar Pradesh     80
# 34                               Uttarakhand      5
# 35                               West Bengal     42

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape data and prepare for CSV
def scrape_data(url):
    # Fetch the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract constituency name from <h2> tag
    constituency_name = "Unknown Constituency"
    h2_tag = soup.find('h2')
    if h2_tag:
        span_tag = h2_tag.find('span')
        if span_tag:
            constituency_name = span_tag.text.split(' - ')[1].split('(')[0].strip()

    # Extracting data from each row
    data_to_save = []
    for row in soup.find_all('tr'):
        data_row = []

        # Skip first and last rows (headers and state summary)
        if row.find('th') or 'State Total' in row.text.strip():
            continue

        # Extracting data from each cell
        for cell in row.find_all('td'):
            data_row.append(cell.text.strip())

        if len(data_row) == 0:
            continue  # Skip empty rows

        data_to_save.append([constituency_name] + data_row)

    return data_to_save

# Dictionary of states and their constituency counts
constituencies_per_state = {
    'Andaman and Nicobar': 1,
    'Andhra Pradesh': 25,
    'Arunachal Pradesh': 2,
    'Assam': 14,
    'Bihar': 40,
    'Chandigarh': 1,
    'Chhattisgarh': 11,
    'Dadra and Nagar Haveli and Daman and Diu': 2,
    'Goa': 2,
    'Gujarat': 26,
    'Haryana': 10,
    'Himachal Pradesh': 4,
    'Jammu and Kashmir': 5,
    'Jharkhand': 14,
    'Karnataka': 28,
    'Kerala': 20,
    'Ladhakh': 1,
    'Lakshadweep': 1,
    'Madhya Pradesh': 29,
    'Maharashtra': 48,
    'Manipur': 2,
    'Meghalaya': 2,
    'Mizoram': 1,
    'NCT OF Delhi': 7,
    'Nagaland': 1,
    'Odisha': 21,
    'Puducherry': 1,
    'Punjab': 13,
    'Rajasthan': 25,
    'Sikkim': 1,
    'Tamil Nadu': 39,
    'Telangana': 17,
    'Tripura': 2,
    'Uttar Pradesh': 80,
    'Uttarakhand': 5,
    'West Bengal': 42
}

# Base URL format for constituency-wise results
base_url = 'https://results.eci.gov.in/PcResultGenJune2024/Constituencywise{code}{i}.htm'

# State codes for URL construction
state_codes = {
    'Andaman and Nicobar': 'U01',
    'Andhra Pradesh': 'S01',
    'Arunachal Pradesh': 'S02',
    'Assam': 'S03',
    'Bihar': 'S04',
    'Chandigarh': 'U02',
    'Chhattisgarh': 'S26',
    'Dadra and Nagar Haveli and Daman and Diu': 'U03',
    'Goa': 'S05',
    'Gujarat': 'S06',
    'Haryana': 'S07',
    'Himachal Pradesh': 'S08',
    'Jammu and Kashmir': 'U08',
    'Jharkhand': 'S27',
    'Karnataka': 'S10',
    'Kerala': 'S11',
    'Ladhakh': 'U09',
    'Lakshadweep': 'U06',
    'Madhya Pradesh': 'S12',
    'Maharashtra': 'S13',
    'Manipur': 'S14',
    'Meghalaya': 'S15',
    'Mizoram': 'S16',
    'Nagaland': 'S17',
    'NCT OF Delhi': 'U05',
    'Odisha': 'S18',
    'Puducherry': 'U07',
    'Punjab': 'S19',
    'Rajasthan': 'S20',
    'Sikkim': 'S21',
    'Tamil Nadu': 'S22',
    'Telangana': 'S29',
    'Tripura': 'S23',
    'Uttar Pradesh': 'S24',
    'Uttarakhand': 'S28',
    'West Bengal': 'S25'
}

# Prepare data to save to CSV
all_data_to_save = []

# Scraping and saving data for each state and each constituency
for state, constituencies in constituencies_per_state.items():
    state_code = state_codes[state]
    for i in range(1, constituencies + 1):
        url = base_url.format(code=state_code, i=str(i) if i < 10 else str(i).zfill(2))
        print(f'Scraping {url}...')
        data_for_constituency = scrape_data(url)
        if data_for_constituency:
            for row in data_for_constituency:
                # Add state and constituency info to the row
                all_data_to_save.append([state] + row)

# Write all data to a single CSV file
csv_filename = 'all_states_election_results_final.csv'
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write headers
    csv_writer.writerow(['State', 'Constituency Name', 'Candidate', 'Party Name', 'EVM Votes', 'Postal Votes', 'Total Votes', 'Percentage of Votes'])
    # Write data
    csv_writer.writerows(all_data_to_save)

print(f'Saved all states election results to {csv_filename}')
# Out:
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU011.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS011.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS012.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS013.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS014.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS015.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS016.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS017.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS018.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS019.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0110.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0111.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0112.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0113.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0114.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0115.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0116.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0117.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0118.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0119.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0120.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0121.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0122.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0123.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0124.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0125.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS021.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS022.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS031.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS032.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS033.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS034.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS035.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS036.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS037.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS038.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS039.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0310.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0311.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0312.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0313.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0314.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS041.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS042.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS043.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS044.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS045.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS046.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS047.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS048.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS049.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0410.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0411.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0412.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0413.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0414.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0415.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0416.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0417.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0418.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0419.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0420.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0421.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0422.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0423.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0424.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0425.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0426.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0427.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0428.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0429.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0430.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0431.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0432.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0433.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0434.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0435.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0436.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0437.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0438.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0439.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0440.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU021.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS261.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS262.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS263.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS264.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS265.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS266.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS267.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS268.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS269.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2610.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2611.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU031.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU032.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS051.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS052.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS061.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS062.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS063.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS064.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS065.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS066.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS067.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS068.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS069.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0610.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0611.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0612.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0613.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0614.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0615.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0616.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0617.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0618.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0619.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0620.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0621.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0622.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0623.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0624.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0625.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0626.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS071.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS072.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS073.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS074.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS075.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS076.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS077.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS078.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS079.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0710.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS081.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS082.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS083.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS084.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU081.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU082.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU083.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU084.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU085.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS271.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS272.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS273.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS274.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS275.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS276.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS277.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS278.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS279.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2710.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2711.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2712.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2713.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2714.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS101.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS102.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS103.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS104.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS105.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS106.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS107.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS108.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS109.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1010.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1011.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1012.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1013.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1014.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1015.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1016.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1017.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1018.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1019.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1020.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1021.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1022.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1023.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1024.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1025.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1026.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1027.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1028.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS111.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS112.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS113.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS114.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS115.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS116.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS117.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS118.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS119.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1110.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1111.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1112.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1113.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1114.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1115.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1116.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1117.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1118.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1119.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1120.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU091.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU061.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS121.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS122.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS123.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS124.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS125.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS126.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS127.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS128.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS129.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1210.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1211.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1212.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1213.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1214.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1215.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1216.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1217.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1218.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1219.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1220.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1221.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1222.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1223.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1224.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1225.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1226.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1227.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1228.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1229.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS131.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS132.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS133.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS134.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS135.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS136.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS137.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS138.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS139.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1310.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1311.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1312.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1313.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1314.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1315.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1316.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1317.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1318.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1319.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1320.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1321.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1322.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1323.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1324.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1325.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1326.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1327.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1328.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1329.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1330.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1331.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1332.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1333.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1334.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1335.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1336.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1337.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1338.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1339.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1340.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1341.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1342.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1343.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1344.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1345.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1346.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1347.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1348.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS141.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS142.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS151.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS152.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS161.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU051.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU052.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU053.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU054.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU055.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU056.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU057.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS171.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS181.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS182.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS183.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS184.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS185.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS186.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS187.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS188.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS189.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1810.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1811.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1812.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1813.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1814.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1815.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1816.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1817.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1818.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1819.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1820.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1821.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU071.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS191.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS192.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS193.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS194.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS195.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS196.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS197.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS198.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS199.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1910.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1911.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1912.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1913.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS201.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS202.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS203.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS204.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS205.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS206.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS207.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS208.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS209.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2010.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2011.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2012.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2013.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2014.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2015.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2016.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2017.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2018.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2019.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2020.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2021.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2022.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2023.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2024.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2025.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS211.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS221.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS222.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS223.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS224.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS225.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS226.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS227.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS228.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS229.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2210.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2211.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2212.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2213.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2214.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2215.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2216.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2217.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2218.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2219.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2220.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2221.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2222.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2223.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2224.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2225.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2226.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2227.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2228.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2229.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2230.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2231.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2232.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2233.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2234.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2235.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2236.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2237.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2238.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2239.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS291.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS292.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS293.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS294.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS295.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS296.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS297.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS298.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS299.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2910.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2911.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2912.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2913.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2914.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2915.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2916.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2917.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS231.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS232.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS241.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS242.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS243.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS244.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS245.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS246.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS247.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS248.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS249.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2410.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2411.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2412.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2413.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2414.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2415.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2416.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2417.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2418.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2419.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2420.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2421.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2422.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2423.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2424.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2425.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2426.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2427.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2428.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2429.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2430.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2431.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2432.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2433.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2434.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2435.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2436.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2437.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2438.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2439.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2440.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2441.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2442.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2443.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2444.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2445.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2446.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2447.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2448.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2449.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2450.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2451.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2452.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2453.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2454.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2455.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2456.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2457.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2458.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2459.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2460.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2461.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2462.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2463.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2464.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2465.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2466.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2467.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2468.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2469.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2470.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2471.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2472.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2473.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2474.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2475.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2476.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2477.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2478.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2479.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2480.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS281.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS282.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS283.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS284.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS285.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS251.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS252.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS253.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS254.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS255.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS256.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS257.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS258.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS259.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2510.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2511.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2512.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2513.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2514.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2515.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2516.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2517.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2518.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2519.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2520.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2521.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2522.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2523.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2524.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2525.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2526.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2527.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2528.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2529.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2530.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2531.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2532.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2533.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2534.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2535.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2536.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2537.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2538.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2539.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2540.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2541.htm...
# Scraping https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS2542.htm...
# Saved all states election results to all_states_election_results_final.csv
